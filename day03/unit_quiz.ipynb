# %%
week=[{},{},{},{},{}]

# %%
import json
a = input('1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')
a1 = {0:0}
del a1[0]
week2=['mon','tue','wed', 'thr', 'fri']
while True:
    if a == '1':
        days = input('mon, tue, wed, thr, fri >>> ')
        while not days in week2:
            days = input('mon, tue, wed, thr, fri >>> ')
        print('-----%s-----'%days)
        for item in sorted(week[week2.index(days)].items(),key=lambda x:x[0]):
            print(f'{item[0]}시 : {item[1]}')
        week[week2.index(days)][input('시간을 입력하세요. 00 ~ 24 입력 >>> ')]= input('할일을 입력하세요. >>> ')
        print('-----%s-----'%days)
        for item in sorted(week[week2.index(days)].items(),key=lambda x:x[0]):
            print(f'{item[0]}시 : {item[1]}')
        a = input('1.일정 입력 및 변경 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')
    
    elif a == '2':
        days = input('mon, tue, wed, thr, fri >>> ')
        while not days in week2:
            days = input('mon, tue, wed, thr, fri >>> ')
        print('-----%s-----'%days)
        for item in sorted(week[week2.index(days)].items(),key=lambda x:x[0]):
            print(f'{item[0]}시 : {item[1]}')
        a = input('1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')
    
    elif a == '3':
        days = input('mon, tue, wed, thr, fri >>> ')
        while not days in week2:
            days = input('mon, tue, wed, thr, fri >>> ')
        print('일정 : ' , week[week2.index(days)])
        time = input('삭제하고자 하는 시간을 입력해주세요. >>> ')
        while not time in week[week2.index(days)].keys():
            time = input('삭제하고자 하는 시간을 입력해주세요. >>> ')
        del week[week2.index(days)][time]
        print('일정 : ' , week[week2.index(days)])
        a = input('1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')

    elif a == '4':
        print('일정관리 프로그램을 종료합니다.')
        f = open('week.json','w')
        json.dump(week,f)
        f.close()
        break
    
    else:
        print('1~4까지의 숫자를 입력하세요.\n')
        a = input('1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')

# %%
import json
a = input('1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')
a1 = {0:0}
del a1[0]
week2=['mon','tue','wed', 'thr', 'fri']
f = open('week.json','r')
data = json.load(f)
f.close()
while True:
    if a == '1':
        days = input('mon, tue, wed, thr, fri >>> ')
        while not days in week2:
            days = input('mon, tue, wed, thr, fri >>> ')
        print('-----%s-----'%days)
        for item in sorted(week[week2.index(days)].items(),key=lambda x:x[0]):
            print(f'{item[0]}시 : {item[1]}')
        week[week2.index(days)][input('시간을 입력하세요. 00 ~ 24 입력 >>> ')]= input('할일을 입력하세요. >>> ')
        print('-----%s-----'%days)
        for item in sorted(week[week2.index(days)].items(),key=lambda x:x[0]):
            print(f'{item[0]}시 : {item[1]}')
        a = input('\n1.일정 입력 및 변경 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')
    
    elif a == '2':
        days = input('mon, tue, wed, thr, fri >>> ')
        while not days in week2:
            days = input('mon, tue, wed, thr, fri >>> ')
        print('-----%s-----'%days)
        for item in sorted(week[week2.index(days)].items(),key=lambda x:x[0]):
            print(f'{item[0]}시 : {item[1]}')
        a = input('\n1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')
    
    elif a == '3':
        days = input('mon, tue, wed, thr, fri >>> ')
        while not days in week2:
            days = input('mon, tue, wed, thr, fri >>> ')
        print('일정 : ' , week[week2.index(days)])
        time = input('삭제하고자 하는 시간을 입력해주세요. >>> ')
        while not time in week[week2.index(days)].keys():
            time = input('삭제하고자 하는 시간을 입력해주세요. >>> ')
        del week[week2.index(days)][time]
        print('일정 : ' , week[week2.index(days)])
        a = input('\n1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')

    elif a == '4':
        print('일정관리 프로그램을 종료합니다.')
        f = open('week.json','w')
        json.dump(week,f)
        f.close()
        break
    
    else:
        print('1~4까지의 숫자를 입력하세요.\n')
        a = input('\n1.일정 입력 및 수정 2.일정목록 3.일정삭제 4.프로그램종료 >>> ')
